# %% [markdown]
# # DAV 6150 Final Project
#
# - by Group Manling Yang, Xiaojia He, Qi Sun
#
#
# ***
# ## Introduction
#
# The purpose of this project is to develop a predictive model for employee attrition. The data used for this project was collected from the personnel records of employees in IBM. This dataset is comprised of 1470 observations with 22 variables.
#
#
# <img src="https://raw.githubusercontent.com/susanqisun/DAV-6150/master/assignments/picture/employee-attrition.jpg" width="500">
#
#
# **Research Questions:**
#
# The following research questions will guide this study:
#
# 1. What are the relationships between attrition and other variables?
#
# 2. What is the best model to predict employees’ attrition?
#
# 3. Which features are most contributed to the response variable?
#
#
#
# **Domain Knowledge:**
#
# Attrition is one of the important issues in an organization. Stovel, M. and Bontis, N. (2002) draw attention on controlling attrition, they state that the value of employees to an organization is a very crucial element in the success of the organization. When employees leave an organization, they carry with them invaluable knowledge which is often the source of competitive advantage for the business. Attrition is defined as the normal and uncontrollable reduction of a work force because of retirement, death, sickness, and relocation. The employee attrition is often unpredictable and can leave gaps in an organization. If organizations know why their employees leave, they can develop effective strategies for employee retention. The purposes of this study are to find out why employees left the organization and to develop a model that can predict how likely the employee quit the job.
#
# There are many reasons why employee leave the organization.
#
# Based on the research of Firth et al (2007), intention to quit is largely influenced by job dissatisfaction, lack of commitment to the organization and feelings of stress. The work overload and job ambiguity which are the factors that trigger the chain of psychological states that lead to intention to quit. Reducing attrition can save organizations the considerable financial cost and effort involved in the recruitment, induction and training of replacement staff.
#
# Griffeth et al. (2000) conclude that the predictors of employee turnover include job satisfaction, organizational commitment, job search, comparison of alternatives, withdrawal cognitions, and quit intentions. Also, job performance can foreshadow turnover. The pay and pay-related variables have a significant effect on employee turnover. The results of the gender-turnover correlation indicates that women turnover rate is similar to that of men. The gender age-turnover relationship demonstrates that women are more likely to remain as they age than are men.
#
# Louis (1980) states that attrition takes place because new employees compare their actual experience with their past work experiences. Past work experience plays a significant role in taking decisions to quit in case the new worker’s expectations are not met.
#
# All the researches mentioned above have been completed over ten years ago. In this study, we’ll examine the factors that can result in employee attrition in IBM. We’ll also develop a model to predict the employee attrition. The outcome of this research can be utilized for redesigning the HR policies and practices and take corrective actions to reduce the attrition rate.
#
#
# ## Arrtibute Information
#
# **Independent variables:**
#
# 1. Age: the age of employees, all of them are over 18. - int, continuous
# 3. BusinessTravel: how frequency of employees’ business travel. - object,categorical data
# 4. DailyRate: the daily income each employee gets from company IBM. - positive integer, discrete
# 5. DistanceFromHome: the distance between each employee’s address and company. - positive integer, continuous
# 6. Education: the education level for each employee. 1 = 'Below College', 2 = 'College', 3 =  'Bachelor', 4 =  'Master', 5 =  'Doctor'   - positive integer  from 1 to 5, categorical data
# 7. EmployeeNumber: the unique index or id of each employee. - positive integer, continuous
# 8. EnvironmentSatisfaction: how does each employee feel for the company working environment. The range is from low to high, 1= 'Low', 2= 'Medium', 3= 'High', 4= 'Very High'. - positive integer from 1 to 4, ordinal data
# 9. Gender: the sex of each employee. Female or male - object, categorical data
# 10. JobInvolvement: a state of psychological identification with each employee’s work—or the degree to which a job is central to a person's identity. 1 = 'Low', 2= 'Medium', 3= 'High', 4= 'Very High',  - positive integer from 1 to 4, ordinal data
# 11. JobLevel: the level of job for each employee - positive integer, discrete
# 12. JobRole: the job title for each employee - object, categorical
# 13. JobSatisfaction: how does each employee feel about his or her job. It is from low to high. 1 = 'Low', 2= 'Medium', 3= 'High', 4= 'Very High',  - positive integer from 1 to 4, ordinal data
# 14. MaritalStatus: the marital status for each employee. Single or Married - Object, categorical data
# 15. OverTime: if the employee works always over time. Yes or no - Object, binary data
# 16. PerformanceRating: the rating of each employee’s performance. 1 ='Low', 2='Good', 3= 'Excellent', 4= 'Outstanding' - positive integer from 1 to 4, ordinal data
# 17. RelationshipSatisfaction:  how does each employee feel about his or her working relationship. 1 = 'Low', 2= 'Medium', 3= 'High', 4= 'Very High',  - positive integer from 1 to 4, ordinal data
# 18. TrainingTimesLastYear: the total training time for each employee from last year. - positive integer or zero, continuous
# 19. WorkLifeBalance: how does each employee feel about the work life balance. 1='Bad', 2= 'Good', 3= 'Better', 4= 'Best'  - positive integer from 1 to 4, ordinal data
# 20. YearsAtCompany: the number of years that each employee stays at the company.  - positive integer or zero, continuous
# 21. YearsWithCurrManager: the number of years that each employee works with the current direct manager.  - positive integer or zero, continuous.
# 22. TotalWorkingYears: the number of total working years for each employee. - positive integer or zero, continuous
#
# **Dependent variable:**
#
# **Attrition**: Attrition is our response variable (binary) to indicate if an employee quit the job. The value includes Yes or No.
#
# ## Reference:
#
# Stovel, M. and Bontis, N. (2002), "Voluntary turnover: knowledge management – friend or foe?", Journal of Intellectual Capital, Vol. 3 No. 3, pp. 303-322.
# https://pdfs.semanticscholar.org/1856/1de816a436871587869169369dfe086ecb6c.pdf
#
# Firth, L., Mellor, D.J., Moore, K.A. and Loquet, C. (2004), "How can managers reduce employee intention to quit?", Journal of Managerial Psychology, Vol. 19 No. 2, pp. 170-187.
# https://pdfs.semanticscholar.org/4ffe/89346438e0d97e4241ca76779e153247d91a.pdf?_ga=2.41973861.1951415783.1594600481-158954980.1590280415
#
#
# Griffeth RW, Hom PW, Gaertner S (2000). "A meta-analysis of antecedents and correlates of employee turnover: update, moderator tests, and research implications for the next millennium", J. Manage. 26 (3): 463-88.
# https://d1wqtxts1xzle7.cloudfront.net/42653895/A_Meta-Analysis_of_Antecedents_and_Corre20160213-22360-fjbwz8.pdf?1455393954=&response-content-disposition=inline%3B+filename%3DA_meta-analysis_of_antecedents_and_corre.pdf&Expires=1594604746&Signature=F6EiCVoswSyNtj9F0jOg-SYlIiP5ZdRS8zc16PjlQyPnJ4qpB07~aLkaINRqyFkmqi13NWogN0gaWnyawe6zuXuelwmMHQICvdZxsaiqO2AjkpDA1vZ8xkQKlEhwdtEvzCO-9NWLXcBDwHYAcHm1R1IpDHaMQ1YzmoV1FKN2qVd8ip0Wa4UGIfIb1VN5lNnV9Q-z0Nx-FlpoYks8BEnO-GvTbfZENTAMvzAVNaD59FOttbx1NH6AXUGfZCdYCKHYQolMzluDEybDEH9jbLWjSg2CHFK9lhKNvSu~Zz1XDFR-2Tnm0~stCwtX6KNX66KNWOig30lasiq9ynho-Vqnvw__&Key-Pair-Id=APKAJLOHF5GGSLRBV4ZA
#
#
# Louis, M.R. (1980), "Surprise and sense-making: what newcomers experience in entering unfamiliar organizational settings", Administrative Science Quarterly, Vol. 25 No.2, pp.226-51.
# http://pdfs.semanticscholar.org/80f2/e6d17eecc0f05dffed9b8c4d740d77373f25.pdf
#
# Data from: https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset?select=WA_Fn-UseC_-HR-Employee-Attrition.csv
#
# ***

# %%
# Importing required libraries.
import pandas as pd
import numpy as np

import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

from sklearn.linear_model import LogisticRegression
from sklearn import linear_model
from sklearn.model_selection import cross_val_score

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, confusion_matrix
from sklearn.metrics import f1_score, roc_auc_score

# Import and suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ***
# ## Step 1: Load data into the data frame from GitHub
#
# After reading the dataset from Github
#
# `.head()` returns the first 5 rows of the dataset.

# %%
# read data from Github
df = pd.read_csv("https://raw.githubusercontent.com/susanqisun/DAV-6150/master/assignments/FinalProject/dav6150_final_dataset.csv")

# To display the top 5 rows
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate  DistanceFromHome  Education  \
# 0   41       Yes      Travel_Rarely       1102                 1          2
# 1   49        No  Travel_Frequently        279                 8          1
# 2   37       Yes      Travel_Rarely       1373                 2          2
# 3   33        No  Travel_Frequently       1392                 3          4
# 4   27        No      Travel_Rarely        591                 2          1
#
#    EmployeeNumber  EnvironmentSatisfaction  Gender  JobInvolvement  ...  \
# 0               1                        2  Female               3  ...
# 1               2                        3    Male               2  ...
# 2               4                        4    Male               2  ...
# 3               5                        4  Female               3  ...
# 4               7                        1    Male               3  ...
#
#    JobSatisfaction MaritalStatus  OverTime PerformanceRating  \
# ...

# %% [markdown]
# ***
# ## Step 2: Exploratory Data Analysis

# %% [markdown]
# ### 1. Data exploration:
# `.shape` returns the number of rows by the number of columns for the dataset.
#
# `.describe()` summarizes the count, mean, standard deviation, min, and max for numeric variables.
#
# `.dtypes` identifies the Data Types.
#
# `.nunique()` returns the number of unique values for each variable.
#
# `.isnull().sum()` checks missing values for each column.
#
# `.count()` returns the count for each variable.

# %%
print(df.shape)
print(list(df.columns))
# Out:
# (1470, 22)
# ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsWithCurrManager']

# %%
df.describe().T
# Out:
#                            count         mean  ...      75%     max
# Age                       1470.0    36.923810  ...    43.00    60.0
# DailyRate                 1470.0   802.485714  ...  1157.00  1499.0
# DistanceFromHome          1470.0     9.192517  ...    14.00    29.0
# Education                 1470.0     2.912925  ...     4.00     5.0
# EmployeeNumber            1470.0  1024.865306  ...  1555.75  2068.0
# EnvironmentSatisfaction   1470.0     2.721769  ...     4.00     4.0
# JobInvolvement            1470.0     2.729932  ...     3.00     4.0
# JobLevel                  1470.0     2.063946  ...     3.00     5.0
# JobSatisfaction           1470.0     2.728571  ...     4.00     4.0
# PerformanceRating         1470.0     3.153741  ...     3.00     4.0
# RelationshipSatisfaction  1470.0     2.712245  ...     4.00     4.0
# TotalWorkingYears         1470.0    11.279592  ...    15.00    40.0
# TrainingTimesLastYear     1470.0     2.799320  ...     3.00     6.0
# ...

# %%
#Identify the Data Types
df_info = pd.DataFrame(df.dtypes,columns=['Dtype'])

#Identify the unique values
df_info['Nunique'] = df.nunique()

#check missing values for each column
df_info['MissingValues']=df.isnull().sum()

# Identify the count for each variable
df_info['Count']=df.count()

# Identify the zero values for each variable
df_info['ZeroValues']=(df==0).sum()

# how many '?' values
df_info['?Values']=(df=='?').sum()

df_info
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#                            Dtype  Nunique  ...  ZeroValues  ?Values
# Age                        int64       43  ...           0        0
# Attrition                 object        2  ...           0        0
# BusinessTravel            object        3  ...           0        0
# DailyRate                  int64      886  ...           0        0
# DistanceFromHome           int64       29  ...           0        0
# Education                  int64        5  ...           0        0
# EmployeeNumber             int64     1470  ...           0        0
# EnvironmentSatisfaction    int64        4  ...           0        0
# Gender                    object        2  ...           0        0
# ...

# %% [markdown]
# 1. Consider some employees who are currently hired, the column TotalWorkingYears, TrainingTimesLastYear, YearsAtCompany, and YearsWithCurrManager are possible to have zero value.  So, there is no missing value and all values are valid.
# 2. There are 44 new employees (YearsAtCompany) and 11 employees (TotalWorkingYears) have less than 1 year of working experience.

# %% [markdown]
# ### 2. Check distribution of numerical variables

# %%
# Distributions for each of numerical variables.
df.hist(figsize=(25, 15), bins=20, xlabelsize=10, ylabelsize=10);

# %% [markdown]
# 1. In the dataset, the main observations are people who are 30 to 40 Age group, have a bachelor's degree (Education=3), and distane from home in 10 miles.
# 2. Most of the employees have high environment satisfaction, Job satisfaction, relationship satisfaction. In addition, they also have high performance rating and good work-life balance.
# 3. Most of the employees' total working years are no more than ten and most of the employees work at this company less than 10 years.

# %% [markdown]
# ### 3. Check distribution of categorical variables

# %%
categorical_columns = ['BusinessTravel', 'Gender',  'MaritalStatus', 'OverTime']

# create the bar chart for each categorical columns
fig, ax = plt.subplots(1, 4, figsize=(25, 8))
for variable, subplot in zip(categorical_columns, ax.flatten()):
    sns.countplot(df[variable], ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(0)

# %%
sns.countplot(df['JobRole']);
plt.xticks(rotation=90);

# %% [markdown]
# 1. Most of the employees travel rarely and have no overtime work.
# 2. Most of the employees are male and married..
# 3. Sales Executive, Research Scientist, and Laboratory Technician are the top 3 main job roles in the company.

# %% [markdown]
# ### 4. Check distribution of dependent variable

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
sns.countplot(x='Attrition',data=df, palette='hls')
plt.show()

# %%
count_no_sub = len(df[df['Attrition']=='No'])
count_sub = len(df[df['Attrition']=='Yes'])
pct_of_no_sub = count_no_sub/(count_no_sub+count_sub)
print("percentage of not left", pct_of_no_sub*100)
pct_of_sub = count_sub/(count_no_sub+count_sub)
print("percentage of left", pct_of_sub*100)
# Out:
# percentage of not left 83.87755102040816
# percentage of left 16.122448979591837

# %% [markdown]
# The response variable is imbalanced, Attrition 'Yes' takes up 16% and Attrition 'No' is 84%. We will use SMOTE function to handle it later.

# %% [markdown]
# ### 5. Check duplicate data

# %%
# Select duplicate rows except first occurrence based on all columns
duplicateRowsDF = df[df.duplicated()]
print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateRowsDF)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, DistanceFromHome, Education, EmployeeNumber, EnvironmentSatisfaction, Gender, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, OverTime, PerformanceRating, RelationshipSatisfaction, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsWithCurrManager]
# Index: []

# %% [markdown]
# There are no duplicated data.

# %% [markdown]
# ### 6. Check the relationships between independent variables and the dependent variable
#
# The EmployeeNumber is the unique index for each employee, it is not meaningful to visualize, so we skip this feature.

# %%
# redefine the numerical column
num_columns = ['Age', 'DailyRate', 'DistanceFromHome', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsWithCurrManager']

#https://towardsdatascience.com/a-starter-pack-to-exploratory-data-analysis-with-python-pandas-seaborn-and-scikit-learn-a77889485baf
def quantitative_summarized(dataframe, x=None, y=None, hue=None, palette='Set1', ax=None, verbose=True, swarm=False):
    sns.boxplot(x=x, y=y, hue=hue, data=dataframe, palette=palette, ax=ax)
    if swarm:
        sns.swarmplot(x=x, y=y, hue=hue, data=dataframe,
                      palette=palette, ax=ax)

    plt.show()
    
for i in num_columns:
    quantitative_summarized(dataframe= df, y = i, x ='Attrition',palette='husl', verbose=False, swarm=True)

# %% [markdown]
# According to the box plot, we can see 'Age', 'DailyRate', 'DistanceFromHome',  'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',  and 'YearsWithCurrManager' might be more predictable to Attrition.

# %%
df1 = df.copy()

# BusinessTravel vs Attrition

plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with BusinessTravel with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'BusinessTravel', data=df1, palette = 'husl')
plt.title('Attrition vs. BusinessTravel')

# check the Attrition percentage of BusinessTravel
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.BusinessTravel, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by BusinessTravel')
plt.xlabel('BusinessTravel')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition           No  Yes
# BusinessTravel
# Non-Travel         138   12
# Travel_Frequently  208   69
# Travel_Rarely      887  156

# %% [markdown]
# For both attrition_Yes and attrition_No, the total number of employees with rare travel is the most.
# employees with frequent Business travel have a higher percentage of attrition_Yes. Employees with no travel have a lowest percentage of attrition_Yes. The BusinessTravel feature might be important to predict the response variable 'Attrition'.

# %%
# Education vs Attrition

plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with Education with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'Education', data=df1, palette = 'husl')
plt.title('Attrition vs. Education')

# check the Attrition percentage of Education
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.Education, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by Education')
plt.xlabel('Education')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition   No  Yes
# Education
# 1          139   31
# 2          238   44
# 3          473   99
# 4          340   58
# 5           43    5

# %% [markdown]
# Each education level has a similar percentage of employees' attrition. The employees who have a bachelor's degree (Education=3) are the main group of employees' attrition_Yes. 'Education' might be relatively more “predictive” of the response variable.

# %%
# EnvironmentSatisfaction vs Attrition

plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with 'EnvironmentSatisfaction with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'EnvironmentSatisfaction', data=df1, palette = 'husl')
plt.title('Attrition vs. EnvironmentSatisfaction')

# check the Attrition percentage of 'EnvironmentSatisfaction
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.EnvironmentSatisfaction, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by EnvironmentSatisfaction')
plt.xlabel('EnvironmentSatisfaction')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition                 No  Yes
# EnvironmentSatisfaction
# 1                        212   72
# 2                        244   43
# 3                        391   62
# 4                        386   60

# %% [markdown]
# The employees with low EnvironmentSatisfaction rate have a higher percentage of Attrition_Yes. For Attrition_Yes, the total number of rating EnvironmentSatisfaction as 2 is the least, but the higher ratings (3 and 4) have relatively higher attrition, so EnvironmentSatisfaction might be an important feature to predict the response variable.

# %%
plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with JobInvolvement with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'JobInvolvement', data=df1, palette = 'husl')
plt.title('Attrition vs. JobInvolvement')

# check the Attrition percentage of JobInvolvement
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.JobInvolvement, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by JobInvolvement')
plt.xlabel('JobInvolvement')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition        No  Yes
# JobInvolvement
# 1                55   28
# 2               304   71
# 3               743  125
# 4               131   13

# %% [markdown]
# The employees with Low Job Involvement rating have a higher percentage of attrition. The Job Involvement feature may appear to be relatively more “predictive” of the response variable.

# %%
# JobLevel vs Attrition

plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with JobLevel with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'JobLevel', data=df1, palette = 'husl')
plt.title('Attrition vs. JobLevel')

# check the Attrition percentage of JobLevel
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.JobLevel, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by JobLevel')
plt.xlabel('JobLevel')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition   No  Yes
# JobLevel
# 1          400  143
# 2          482   52
# 3          186   32
# 4          101    5
# 5           64    5

# %% [markdown]
# Low Job Level employees have a higher percentage of attrition. And the middle level 3 is the second. It is a normal phenomenon for low-level employees to leave the company. The Job Level might be relatively more “predictive” of the response variable.

# %%
# JobSatisfaction vs Attrition

plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with JobSatisfaction with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'JobSatisfaction', data=df1, palette = 'husl')
plt.title('Attrition vs. JobSatisfaction')

# check the Attrition percentage of JobSatisfaction
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.JobSatisfaction, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by JobSatisfaction')
plt.xlabel('JobSatisfaction')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition         No  Yes
# JobSatisfaction
# 1                223   66
# 2                234   46
# 3                369   73
# 4                407   52

# %% [markdown]
# The employees who have lower ratings are the main group of employees' attrition_Yes. The Job Satisfaction feature may appear to be relatively more “predictive” of the response variable.

# %%
# PerformanceRating vs Attrition

plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with PerformanceRating with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'PerformanceRating', data=df1, palette = 'husl')
plt.title('Attrition vs. PerformanceRating')

# check the Attrition percentage of PerformanceRating
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.PerformanceRating, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by PerformanceRating')
plt.xlabel('PerformanceRating')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition            No  Yes
# PerformanceRating
# 3                  1044  200
# 4                   189   37

# %% [markdown]
# Both Attrition_Yes and Attrition_No have similar percentage of employees' attrition. The performance rating may not be an important feature to predicate the response variable.

# %%
# RelationshipSatisfaction vs Attrition

plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with RelationshipSatisfaction with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'RelationshipSatisfaction', data=df1, palette = 'husl')
plt.title('Attrition vs. RelationshipSatisfaction')

# check the Attrition percentage of RelationshipSatisfaction
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.RelationshipSatisfaction, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by RelationshipSatisfaction')
plt.xlabel('RelationshipSatisfaction')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition                  No  Yes
# RelationshipSatisfaction
# 1                         219   57
# 2                         258   45
# 3                         388   71
# 4                         368   64

# %% [markdown]
# The highest Relationship Satisfaction rating (4) has more Attrition_Yes than the Relationship Satisfaction rating 2. It may appear to be relatively more “predictive” of the response variable.

# %%
# JobRole vs Attrition

plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with JobRole with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'JobRole', data=df1, palette = 'husl')
plt.title('Attrition vs. JobRole')

# check the Attrition percentage of JobRole
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.JobRole, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by JobRole')
plt.xlabel('JobRole')
plt.xticks(rotation=90)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition                   No  Yes
# JobRole
# Healthcare Representative  122    9
# Human Resources             40   12
# Laboratory Technician      197   62
# Manager                     97    5
# Manufacturing Director     135   10
# Research Director           78    2
# Research Scientist         245   47
# Sales Executive            269   57
# Sales Representative        50   33

# %% [markdown]
# The human resources, laboratory technician, and sales representatives are the top three groups in the high percentage of attrition. The sales representatives group has the highest. The Job Role group may appear to be relatively more “predictive” of the response variable.

# %%
plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with MaritalStatus with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'MaritalStatus', data=df1, palette = 'husl')
plt.title('Attrition vs. MaritalStatus')

# check the Attrition percentage of MaritalStatus
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.MaritalStatus, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by MaritalStatus')
plt.xlabel('MaritalStatus')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition       No  Yes
# MaritalStatus
# Divorced       294   33
# Married        589   84
# Single         350  120

# %% [markdown]
# Single employees have the highest percentage of attrition. It may appear to be relatively more “predictive” of the response variable.

# %%
plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with OverTime with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'OverTime', data=df1, palette = 'husl')
plt.title('Attrition vs. OverTime')

# check the Attrition percentage of OverTime
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.OverTime, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by OverTime')
plt.xlabel('OverTime')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition   No  Yes
# OverTime
# No         944  110
# Yes        289  127

# %% [markdown]
# Overtime working employees have a higher percentage of Attrition_Yes than the employees with no overtime work. It may appear to be relatively more “predictive” of the response variable.

# %%
# WorkLifeBalance vs Attrition

plt.rcParams['figure.figsize'] = (10, 5)

# compare the year with WorkLifeBalance with Attrition
plt.subplot(121)
sns.countplot(x='Attrition',hue= 'WorkLifeBalance', data=df1, palette = 'husl')
plt.title('Attrition vs. WorkLifeBalance')

# check the Attrition percentage of WorkLifeBalance
ax= plt.subplot(122)
c2_c = pd.crosstab(df1.WorkLifeBalance, df1.Attrition)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Attrition Percentage by WorkLifeBalance')
plt.xlabel('WorkLifeBalance')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Attrition')

c2_c
# Out:
# Attrition         No  Yes
# WorkLifeBalance
# 1                 55   25
# 2                286   58
# 3                766  127
# 4                126   27

# %% [markdown]
# Employees with lowest Worklife Balance have a higher percentage of attrition_Yes. However, employees with highest Worklife Balance have a second highest percentage of attrition_Yes. It may be an important feature to predict Attrition.

# %% [markdown]
# ***
# ## Step 3: Data Cleaning

# %% [markdown]
# ### 1. Drop irrelevant columns column 'EmployeeNumber'
#
# We'll drop the column 'EmployeeNumber' since it is meaningless to predict attrition.

# %%
df2 = df.copy()

# drop column EmployeeNumber
df3 = df2.drop(columns = ['EmployeeNumber'])

# %% [markdown]
# ### 2. Label the binary dependent variable
#
# The dependent variable 'Attrition' has two values, Yes/No. We'll label the value of Attrition.

# %%
df4 = df3.replace({'Attrition':{'Yes':1,'No':0}})
df4['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %% [markdown]
# ### 3. Convert categorical variable into dummy variables
#
# We'll convert categorical variable into dummy variables and get k-1 dummies out of k categorical levels by removing the first level.

# %%
# create dummy for categorical data
categorical_independent = ['BusinessTravel', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']

df_dummy = pd.get_dummies(df4,columns=categorical_independent,drop_first=True)

# %% [markdown]
# ### 4. Feature Scaling using MinMaxScaler (except dummy variables)
#
# Before doing feature scaling, we'll split data into training and testing subsets by using the `train_test_split` function.
#
# Since some variables have different scales, we'll use `MinMaxScaler` to transform features by scaling each feature to a given range. This range is set at (0,1). We'll not perform feature scaling for dummy variables.

# %%
from sklearn.model_selection import train_test_split

df_final = df_dummy.copy()

# Create X and y
X = df_final.drop(["Attrition"],axis=1)
y = df_final[['Attrition']]

# Now split the data into training and testing subsets. 
X_train01, X_test01, y_train01, y_test01 = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
# set up non-dummy variables
columns_std=['Age',
 'DailyRate',
 'DistanceFromHome',
 'Education',
 'EnvironmentSatisfaction',
 'JobInvolvement',
 'JobLevel',
 'JobSatisfaction',
 'PerformanceRating',
 'RelationshipSatisfaction',
 'TotalWorkingYears',
 'TrainingTimesLastYear',
 'WorkLifeBalance',
 'YearsAtCompany',
 'YearsWithCurrManager']

# %%
# plot numerical features (non-dummy features) before scaling
sns.catplot(data=df3[columns_std], kind='box' , aspect=1.5);
plt.xticks(rotation=90);

# %%
from sklearn.preprocessing import MinMaxScaler

# Applying Feature Scaling
sc = MinMaxScaler()
X_train01[columns_std] = sc.fit_transform(X_train01[columns_std])

X_test01[columns_std] = sc.transform(X_test01[columns_std])

# %%
# plot after Applying Feature Scaling ( MinMaxScaler )
sns.catplot(data=X_train01[columns_std] , kind='box' , aspect=1.5);
plt.xticks(rotation=90);

# %% [markdown]
# ***
# ## Step4. Prepped Data Review
#
# ### 1) Check columns:
#
# The total number of columns has changed from 22 to 30.

# %%
print("Check the column names:", df_dummy.columns.tolist())
print("\n")
print("Total number of columns: ", len(df_dummy.columns.tolist()))
# Out:
# Check the column names: ['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'PerformanceRating', 'RelationshipSatisfaction', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsWithCurrManager', 'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely', 'Gender_Male', 'JobRole_Human Resources', 'JobRole_Laboratory Technician', 'JobRole_Manager', 'JobRole_Manufacturing Director', 'JobRole_Research Director', 'JobRole_Research Scientist', 'JobRole_Sales Executive', 'JobRole_Sales Representative', 'MaritalStatus_Married', 'MaritalStatus_Single', 'OverTime_Yes']
#
#
# Total number of columns:  30

# %% [markdown]
# ### 2) Check the shape of the data set

# %%
print('Training Features Shape:', X_train01.shape)
print('Testing Features Shape:', X_test01.shape)
# Out:
# Training Features Shape: (1176, 29)
# Testing Features Shape: (294, 29)

# %% [markdown]
# ### 3) Check distributions for each of numerical variables

# %%
# Distributions for each variable
X_train01.hist(figsize=(20, 20), bins=20, xlabelsize=10, ylabelsize=10);

# %% [markdown]
# The values of all variables are between 0 and 1.
#
# ***
#
# ## Step 5: Machine Learning Models
#
# The goal of this project is to develop a predictive model for employee attrition. Since the dependent variable of this project is 'attrition' (yes/no) that is a binary variable, we'll develop classification models to predict the class labels for the new data. The classification algorithms that we are going to use are Binary Logistic regression, KNN, SVM, Decision Trees, and Random Forest.

# %% [markdown]
# ### 1. Over-sampling using SMOTE
#
# SMOTE (Synthetic Minority Over-sampling Technique) is a type of over-sampling procedure that is used to correct the imbalances in the groups. Researchers have found that balancing the data will to better classification models.
#
# This technique creates new data instances of the minority groups by copying existing minority instances and making small changes to them. This makes SMOTE great at amplifying signals that already exist in the minority groups, but won’t create new information for those groups.

# %%
from imblearn.over_sampling import SMOTE

os = SMOTE(random_state=0)
columns = X_train01.columns
X_resampled_test,y_resampled_test=os.fit_sample(X_train01, y_train01)

os_data_X = pd.DataFrame(data=X_resampled_test,columns=columns )
os_data_y= pd.DataFrame(data=y_resampled_test,columns=['Attrition'])

# %%
# observe balanced data 
sns.countplot(x='Attrition', data=os_data_y)

# %% [markdown]
# **Check the null error rate:**
#
# Null Error Rate is how often you would be wrong if you always predicted the majority class.

# %%
# null error rate of balanced dataset

# set up dataset after SMOTE
data_train = pd.concat([os_data_X, os_data_y], axis=1)

# what percentage of the training set attrition_No?
data_train.Attrition.values.sum() / data_train.shape[0]
# Out:
# 0.5

# %%
# Null error rate of the original dataset
1 - df4.Attrition.values.sum() / df4.shape[0]
# Out:
# 0.8387755102040817

# %% [markdown]
# The null error rate of the imbalanced trianing dataset is 84%, which is great but not reliable since the dataset is imbalanced. After using 'SMOTE' to balance the dataset, the null error rate for the balanced training dataset is reduced from 84% to 50%.

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train01['Attrition']==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train01['Attrition']==0)))

print('After OverSampling, the shape of train_X: {}'.format(os_data_X.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(os_data_y.shape))

print("After OverSampling, counts of label '1': {}".format(sum(os_data_y['Attrition']==1)))
print("After OverSampling, counts of label '0': {}".format(sum(os_data_y['Attrition']==0)))
# Out:
# Before OverSampling, counts of label '1': 189
# Before OverSampling, counts of label '0': 987
#
# After OverSampling, the shape of train_X: (1974, 29)
# After OverSampling, the shape of train_y: (1974, 1)
#
# After OverSampling, counts of label '1': 987
# After OverSampling, counts of label '0': 987

# %% [markdown]
# **Split data into training and testing subsets:**
#
# Then, we'll split the balanced training data set into the training and testing sets.

# %%
# Now split the balanced data into training and testing subsets. 
X_train, X_test, y_train, y_test = train_test_split(os_data_X, os_data_y, test_size=0.2, random_state=0)

# check the results
print('Training dataset shape:', X_train.shape, y_train.shape)
print('Testing dataset shape:', X_test.shape, y_test.shape)
# Out:
# Training dataset shape: (1579, 29) (1579, 1)
# Testing dataset shape: (395, 29) (395, 1)

# %% [markdown]
# ### 2. Feature Selection - Tree-based `SelectFromModel`
#
#
# We'll also use SelectFromModel RandomForest to select features based on feature importance. We calculate feature importance using node impurities in each decision tree. In Random forest, the final feature importance is the average of all decision tree feature importance.
#
# https://towardsdatascience.com/the-5-feature-selection-algorithms-every-data-scientist-need-to-know-3a6b566efd2

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), max_features=20)
embeded_rf_selector.fit(X_train, y_train.values.ravel())

embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X_train.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
print(embeded_rf_feature)
# Out:
# 15 selected features
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'RelationshipSatisfaction', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsWithCurrManager', 'OverTime_Yes']

# %% [markdown]
# **Set up a final training and testing data sets with the best features:**

# %%
# columns with 15 selected features
columns_final = ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 
                  'JobLevel', 'JobSatisfaction', 'RelationshipSatisfaction', 'TotalWorkingYears', 'TrainingTimesLastYear', 
                  'WorkLifeBalance', 'YearsAtCompany', 'YearsWithCurrManager', 'OverTime_Yes']

# Model with five features:
X_train_new = X_train[columns_final]

X_test_new = X_test[columns_final]

print('Training Features Shape:', X_train_new.shape)
print('Testing Features Shape:', X_test_new.shape)
# Out:
# Training Features Shape: (1579, 15)
# Testing Features Shape: (395, 15)

# %% [markdown]
# The features selected in this step corresponds to our domain knowledge findings. Therefore, we'll use these 15 features for Classifier Modeling. They are 'Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'RelationshipSatisfaction', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsWithCurrManager', and 'OverTime_Yes'.

# %% [markdown]
# ### 3. Machine Learning Models
#
#
# We'll use Logistic regression, KNN, SVM, Decision Trees, and Random Forest to build models.
#
# We'll tune parameters by using `RandomizedSearchCV`. Random search differs from grid search mainly in that it searches the specified subset of hyperparameters randomly instead of exhaustively. `RandomizedSearchCV` decreases the processing time since it goes through only a fixed number of hyperparameter settings. It moves within the grid in random fashion to find the best set hyperparameters.
#
# We'll compare the base model and the tuned model by using 5-fold cross validation and evaluate models based on accuracy, recall, F1, precision, and roc_auc scores.
#
# **Create a function for model evaluation on the training set:**

# %%
# Create a function for Model Evaluation Using Cross-Validation
def cross_val_score_multilabel (model, X_train, y_train):
    accuracy_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')
    recall = cross_val_score(model, X_train, y_train, cv=5, scoring='recall')
    f1 = cross_val_score(model, X_train, y_train, cv=5, scoring='f1')
    precision = cross_val_score(model, X_train, y_train, cv=5, scoring='precision')
    roc_auc = cross_val_score(model, X_train, y_train, cv=5, scoring='roc_auc')
    print('Model Mean Accuracy (training set):{} '.format(np.mean(accuracy_scores)))
    print(' Recall (training set):{} '.format(np.mean(recall)))
    print(' F1 score (training set):{} '.format(np.mean(f1)))
    print(' precision (training set):{} '.format(np.mean(precision)))
    print(' roc_auc score (training set):{} '.format(np.mean(roc_auc)))

# %% [markdown]
# ### 3.1 Logistic Regression
#
#
# **1) Build Logistic Regression model with default parameters**

# %%
# print all the default parameters
LR_model = LogisticRegression()

from pprint import pprint

# Look at default parameters 
print('Parameters currently in use:\n')
pprint(LR_model.get_params())
# Out:
# Parameters currently in use:
#
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
# build model with defaul parameters
LR_model.fit(X_train_new, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **2) Use RandomizedSearchCV for optimizing parameters**
#
# Logistic regression does not really have any critical hyperparameters to tune. Sometimes, you can see useful differences in performance or convergence with different solvers (solver). solver in [‘newton-cg’, ‘lbfgs’, ‘liblinear’, ‘sag’, ‘saga’]
#
# Regularization (penalty) can sometimes be helpful. penalty in [‘none’, ‘l1’, ‘l2’, ‘elasticnet’]
# Note: not all solvers support all regularization terms.
#
# The C parameter controls the penality strength, which can also be effective.
# C in [100, 10, 1.0, 0.1, 0.01]

# %%
from sklearn.model_selection import RandomizedSearchCV 

# Creating the hyperparameter   
param_dist = {'penalty': ['l2'],
              'C': [0.01, 0.1, 1, 10, 100]} 

# Instantiating classifier 
LR_model02 = LogisticRegression() 
  
# Instantiating RandomizedSearchCV object 
LR_tuned_model = RandomizedSearchCV(LR_model02, param_dist, cv = 5) 
  
LR_tuned_model.fit(X_train_new, y_train.values.ravel()) 
  
# Print the tuned parameters and score 
print("Tuned Logistic Regression Parameters: {}".format(LR_tuned_model.best_params_)) 
print("Best score is {}".format(LR_tuned_model.best_score_))
# Out:
# Tuned Logistic Regression Parameters: {'penalty': 'l2', 'C': 0.1}
# Best score is 0.7314641618963154

# %% [markdown]
# After tunning our parameter, We can see that 12 is the optimal value for ‘penalty’ and 0.1 is the optimal value for 'c'. We will use these parameters to build the tuned model.

# %% [markdown]
# **3) Logistic Regression Model with tuned parameters**

# %%
LR_tuned_model02 = LogisticRegression(penalty='l2', C= 0.1)

#fit the model.
LR_tuned_model02.fit(X_train_new, y_train.values.ravel())
# Out:
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# **4) Evaluate Logistic Regression Model**

# %%
# use the evaluate function above for the base model
cross_val_score_multilabel(LR_model, X_train_new, y_train)
# Out:
# Model Mean Accuracy (training set):0.7485674100863975
#  Recall (training set):0.7692779503105591
#  F1 score (training set):0.7565442225304964
#  precision (training set):0.744504478467739
#  roc_auc score (training set):0.8224694700460828

# %%
# use the evaluate function above for the tuned model
cross_val_score_multilabel(LR_tuned_model02, X_train_new, y_train)
# Out:
# Model Mean Accuracy (training set):0.7555294354028532
#  Recall (training set):0.7705900621118011
#  F1 score (training set):0.7622586468027645
#  precision (training set):0.7545118954862653
#  roc_auc score (training set):0.8202866547606205

# %% [markdown]
# **Results:  Logistic Regression Model Evaluation:**
#
#
# | Metric        | Logistic Regression base model | Logistic Regression tuned model |
# | ------------- | ------- | ------- |
# | # Indep. Vars |  15     |   15     |
# | The Accuracy of the model  | 0.749  | 0.756 |
# |  Recall           |0.769 | 0.771 |
# |  F1 Score      | 0.757  |0.762 |
# |  precision           |0.745 | 0.755 |
# |  roc_auc Score      | 0.822  |0.820 |
#
#
# From the results above, the tuned Logistic regression model did perform better than the base model. We can see that the tuned model has higher accuracy, F1, recall, precision, and roc_auc scores comparing to the base model. Also, the accuracy of the tuned model is higher than the null error rate. Therefore, we choose the tuned model as our preferred logistic regression model.

# %% [markdown]
# ### 3.2  K-Nearest Neighbors (KNN)
#
# We'll firstly build baseline model using the default hyperparameters. Then we'll use `RandomizedSearchCV` here for optimizing parameters.

# %% [markdown]
# **1) Check default hyperparameters of KNN Model:**

# %%
# print all the default parameters in the KNeighborsClassifier
KNN01 = KNeighborsClassifier()

from pprint import pprint

# Look at default parameters 
print('Parameters currently in use:\n')
pprint(KNN01.get_params())
# Out:
# Parameters currently in use:
#
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %% [markdown]
# **2) Create base KNN model with default hyperparameters:**
#
# We will use the 15 features deriving from our feature selection to build the base model.

# %%
# Instantiate
# default criterion=gini
KNN01 = KNeighborsClassifier()

#fit the model.
KNN01.fit(X_train_new, y_train.values.ravel())
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %% [markdown]
# **3) Use `RandomizedSearchCV` for optimizing parameters**
#
# To find the best KNN model, we should find out the most appropriate hyperparameter and then using the tunning hyperparameter to build model. We'll tune the following hyperparameters in this step:
#
# 'n_neighbors': default=5 Number of neighbors to use by default for kneighbors queries.
#
# 'p': default=2 Power parameter for the Minkowski metric. When p = 1, this is equivalent to using manhattan_distance (l1), and euclidean_distance (l2) for p = 2.
#
# https://medium.com/datadriveninvestor/k-nearest-neighbors-in-python-hyperparameters-tuning-716734bc557f

# %%
from sklearn.model_selection import RandomizedSearchCV 

# Creating the hyperparameter   
param_dist = {'n_neighbors':np.arange(1, 25),
              'p': [1,2],
              'leaf_size': list(range(1,50))} 
  
# Instantiating KNN classifier 
KNN = KNeighborsClassifier() 
  
# Instantiating RandomizedSearchCV object 
KNN_cv = RandomizedSearchCV(KNN, param_dist, cv = 5) 
  
KNN_cv.fit(X_train_new, y_train.values.ravel()) 
  
# Print the tuned parameters and score 
print("Tuned KNN Parameters: {}".format(KNN_cv.best_params_)) 
print("Best score is {}".format(KNN_cv.best_score_))
# Out:
# Tuned KNN Parameters: {'p': 1, 'n_neighbors': 3, 'leaf_size': 49}
# Best score is 0.8771167369901546

# %% [markdown]
# After tunning our parameter, We can see that 3 is the optimal value for ‘n_neighbors’ and 1 (manhattan_distance) is the optimal value for 'p', 49 is the optimal value for leaf_size. We will use the best parameters to build the knn model.
#
# **4) KNN Model with tuned parameters**

# %%
#Create new KNN object
KNN02 = KNeighborsClassifier(p= 1, n_neighbors= 3, leaf_size=49)

#fit the model.
KNN02.fit(X_train_new, y_train.values.ravel())
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=49, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=1,
#                      weights='uniform')

# %% [markdown]
# **5) KNN Models Evaluation on training set**

# %%
# base model: 
cross_val_score_multilabel (KNN01, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.8068454892505524
#  Recall (training set):0.9427018633540373
#  F1 score (training set):0.832265962332667
#  precision (training set):0.7452805098845247
#  roc_auc score (training set):0.8990671779716308

# %%
# tuned model: 
cross_val_score_multilabel (KNN02, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.8771167369901546
#  Recall (training set):0.9513897515527949
#  F1 score (training set):0.887574290451868
#  precision (training set):0.8323812164234816
#  roc_auc score (training set):0.934677566093327

# %% [markdown]
# **Results:  KNN Model Evaluation:**
#
#
# | Metric        | KNN base model | KNN tuned model |
# | ------------- | ------- | ------- |
# | # Indep. Vars |  15     |   15     |
# | The Accuracy of the model  | 0.807  | 0.877 |
# |  Recall           |0.943 | 0.951 |
# |  F1 Score      | 0.832  |0.888 |
# |  precision           |0.745 | 0.832 |
# |  roc_auc Score      | 0.899  |0.935 |
#
#
# From the results above, the tuned KNN model did perform better than the base model. We can see that the tuned model has higher accuracy, F1, recall, precision, and roc_auc scores comparing to the base model. Also, the accuracy of the tuned model is higher than the null error rate. Therefore, we choose the tuned model KNN02 as our best and final KNN model.

# %% [markdown]
# ### 5.2 SVM model
#
# SVM uses the concept of margin classification, wherein we attempt to identify classifications within a data set by deriving a decision boundary that maximizes the distance between groups of data points.
#
# **1) Check default hyperparameters of SVM Model:**

# %%
from sklearn.svm import SVC
SVC01 = SVC()

from pprint import pprint

# Look at default parameters 
print('Parameters currently in use:\n')
pprint(SVC01.get_params())
# Out:
# Parameters currently in use:
#
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# **2) Create base SVM model with default hyperparameters:**

# %%
# Instantiate
SVC01 = SVC()

#fit the model.
SVC01.fit(X_train_new, y_train.values.ravel())
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# **3) Use RandomizedSearchCV for optimizing parameters**
#
# Next, we'll use RandomSearchCV to find the best parameter combination. We'll tune the following hyperparameters:
#
# 'Kernels': default=’rbf’: The main function of the kernel is to take low dimensional input space and transform it into a higher-dimensional space.
#
# 'Gamma': default=’scale (1)’: It defines how far influences the calculation of plausible line of separation.
#
# 'C (Regularisation)': default=1.0 : C is the penalty parameter, which represents misclassification or error term.
#
# https://www.geeksforgeeks.org/svm-hyperparameter-tuning-using-gridsearchcv-ml/

# %%
from sklearn.model_selection import RandomizedSearchCV 
from sklearn.svm import SVC

# Creating the hyperparameter   
param_dist = {'C': [10, 1.0, 0.1, 0.01],  
              'gamma': ['scale'], 
              'kernel': ['poly', 'rbf', 'sigmoid']} 
  
# Instantiating SVC classifier 
SVC = SVC()
  
# Instantiating RandomizedSearchCV object 
SVC_cv = RandomizedSearchCV(SVC, param_dist, cv = 5) 
  
SVC_cv.fit(X_train_new, y_train.values.ravel()) 
  
# Print the tuned parameters and score 
print("Tuned svc Parameters: {}".format(SVC_cv.best_params_)) 
print("Best score is {}".format(SVC_cv.best_score_))
# Out:
# Tuned svc Parameters: {'kernel': 'rbf', 'gamma': 'scale', 'C': 10}
# Best score is 0.8701667671287925

# %% [markdown]
# After tuning the parameters, we can see that our best 'kernel'is 'rbf', best "gamma" is "scale" and best 'C'is 10. We will use the best parameters for the SVM model next.
#
# **4) SVM Model with tuned parameters**

# %%
from sklearn.svm import SVC

#Create new SVC object
SVC02 = SVC( kernel = "rbf", gamma = "scale", C= 10)

#fit the model.
SVC02.fit(X_train_new, y_train.values.ravel())
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# **5) SVM Models Evaluation on training set**

# %%
# base model: 
cross_val_score_multilabel (SVC01, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.8239260598754269
#  Recall (training set):0.8117468944099379
#  F1 score (training set):0.8238506137357178
#  precision (training set):0.8369564153458373
#  roc_auc score (training set):0.9036256081459447

# %%
# tuned model: 
cross_val_score_multilabel (SVC02, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.8701667671287925
#  Recall (training set):0.9064363354037267
#  F1 score (training set):0.8763206575496312
#  precision (training set):0.8485015233946003
#  roc_auc score (training set):0.9416949470585514

# %% [markdown]
# **SVM Model Evaluation Results:**
#
#
# | Metric        | SVM base model | SVM tuned model |
# | ------------- | ------- | ------- |
# | # Indep. Vars |  15     |   15     |
# | The Accuracy of the model  | 0.824  | 0.870 |
# |  Recall           |0.812 | 0.906 |
# |  F1 Score      | 0.824  |0.876 |
# |  precision           |0.837 | 0.849 |
# |  roc_auc Score      | 0.904  |0.942 |
#
#
# From the results above, the tuned SVM model did perform better than the base model. We can see that the tuned model has higher accuracy, F1, recall precision and f1 scores comparing to the base model. The accuracy of tuned model is higher than the null error rate. So we select the tuned model as our preferred model.

# %% [markdown]
# ### 5.3  Decision Tree model
#
# A decision tree is a tree-like graph with nodes representing the place where we pick an attribute and ask a question; edges represent the answers the to the question; and the leaves represent the actual output or class label.
#
# **1) Check default hyperparameters of Decision Tree Model:**

# %%
# print all the default parameters in the DecisionTree model
from sklearn.tree import DecisionTreeClassifier
dtc01 = DecisionTreeClassifier(random_state = 0)

from pprint import pprint

# Look at default parameters 
print('Parameters currently in use:\n')
pprint(dtc01.get_params())
# Out:
# Parameters currently in use:
#
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': 'deprecated',
#  'random_state': 0,
#  'splitter': 'best'}

# %% [markdown]
# **2) Create Decision Tree model with default hyperparameters:**

# %%
from sklearn.tree import DecisionTreeClassifier

# Instantiate
dtc01 = DecisionTreeClassifier(random_state=0)

dtc01.fit(X_train_new, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %% [markdown]
# **3) Use `RandomizedSearchCV` for optimizing parameters**
#
# We'll tune some important parameters:
#
# 'max_depthint': default=None, The maximum depth of the tree.
#
# 'max_features': {“auto”, “sqrt”, “log2”}, default=None. The number of features to consider when looking for the best split.
#
# 'min_samples_leaf': default=1, the minimum number of samples required to be at a leaf node.
#
# 'criterion': {“gini”, “entropy”}, default=”gini”. The function to measure the quality of a split.

# %%
from scipy.stats import randint 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import RandomizedSearchCV 

# Creating the hyperparameter grid  
param_dist = {"max_depth": [3,5,6,7,8], 
              'max_features': ['auto', 'sqrt', 'log2'],
              "min_samples_leaf": randint(1, 9), 
              'min_samples_split': [2, 4, 6],
              "criterion": ["gini", "entropy"]} 
  
# Instantiating Decision Tree classifier 
tree = DecisionTreeClassifier() 
  
# Instantiating RandomizedSearchCV object 
tree_cv = RandomizedSearchCV(tree, param_dist, cv = 5) 
  
tree_cv.fit(X_train_new, y_train.values.ravel()) 
  
# Print the tuned parameters and score 
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_)) 
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# Best score is 0.8075025115531445

# %% [markdown]
# **4) Decision Tree Model with tuned parameters**

# %%
# tuned model:
dtc02 = DecisionTreeClassifier(random_state = 0, max_depth = 7, max_features='auto', criterion= 'entropy',    
                                      min_samples_split = 2, min_samples_leaf= 2)

dtc02.fit(X_train_new,y_train.values.ravel())
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=7, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %% [markdown]
# **5) Decision Tree Model Evaluation on training set**

# %%
# base model:
cross_val_score_multilabel (dtc01, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.838495077355837
#  Recall (training set):0.8490760869565218
#  F1 score (training set):0.8425078757026047
#  precision (training set):0.8377318037159114
#  roc_auc score (training set):0.8382683991441005

# %%
# tuned model:
cross_val_score_multilabel (dtc02, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.7663070122563793
#  Recall (training set):0.7517701863354038
#  F1 score (training set):0.7651390572972007
#  precision (training set):0.7811114985634612
#  roc_auc score (training set):0.822893055737507

# %% [markdown]
# **Decision Tree Model Evaluation Results:**
#
#
# | Metric        | Decision Tree base model | Decision Tree tuned model |
# | ------------- | ------- | ------- |
# | # Indep. Vars |  15     |   15     |
# | The Accuracy of the model  | 0.838  | 0.766 |
# |  Recall           |0.849 |  0.752 |
# |  F1 Score      | 0.843  |0.765 |
# |  precision           |0.838 | 0.781 |
# |  roc_auc Score      | 0.838  |0.823  |
#
#
# From the results above, the base Decision Tree model performed better than the tuned model. We can see that the base model has higher accuracy, recall, F1, ROC and precision scores comparing to the tuned model. So in our Decisison Tree models, we select the base model as our preferred model.

# %% [markdown]
# ### 5.4 Random Forest
#
# **1) Check default hyperparameters of Random Forest model**

# %%
from sklearn.ensemble import RandomForestClassifier

rf01 = RandomForestClassifier(random_state = 0)
from pprint import pprint

# Look at default parameters 
print('Parameters currently in use:\n')
pprint(rf01.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# **2) Define and Train the Base Model with default hyperparameters**

# %%
rf01 = RandomForestClassifier(random_state=0)
rf01.fit(X_train_new, y_train.values.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %% [markdown]
# **3) Use `RandomizedSearchCV` for optimizing parameters**
#
# The parameters that we are going to adjust are:
#
# 'n_estimatorsint': default=100, the number of trees in the forest.
#
# 'max_features': {“auto”, “sqrt”, “log2”}, default=”auto”. The number of features to consider when looking for the best split.
#
# 'max_depth': default=None, the maximum depth of the tree.
#
# 'min_samples_split': default=2, the minimum number of samples required to split an internal node.
#
# 'min_samples_leaf': default=1, the minimum number of samples required to be at a leaf node.
#
# 'bootstrapbool': default=True, whether bootstrap samples are used when building trees. If False, the whole dataset is used to build each tree.

# %%
# Creating the hyperparameter grid 
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]


model_params = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# create random forest classifier model
rf_model = RandomForestClassifier(random_state=0)

# Instantiating RandomizedSearchCV object 
#clf02 = RandomizedSearchCV(rf_model, model_params, cv=5)

clf02.fit(X_train_new, y_train.values.ravel()) 

# Print the tuned parameters and score 
print("Tuned Random Forest Parameters: {}".format(clf02.best_params_)) 
print("Best score is {}".format(clf02.best_score_))
# Out:
# Tuned Random Forest Parameters: {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 40, 'bootstrap': True}
# Best score is 0.9138758288125377

# %% [markdown]
# **4) Random Forest model with tuned parameters**

# %%
# tuned model:
rf02 = RandomForestClassifier(
                       criterion='entropy', max_depth=40, max_features='auto',
                       min_samples_split=5, min_samples_leaf=1, 
                       n_estimators=200,
                       random_state=0)

rf02.fit(X_train_new,y_train.values.ravel())
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=40, min_samples_split=5,
#                        n_estimators=200, random_state=0)

# %% [markdown]
# **5) Random Forest Model Evaluation on training set**

# %%
# base model:
cross_val_score_multilabel (rf01, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.9113381555153707
#  Recall (training set):0.8778183229813663
#  F1 score (training set):0.9096259815049079
#  precision (training set):0.9441890425221058
#  roc_auc score (training set):0.9689960417533612

# %%
# tuned model:
cross_val_score_multilabel (rf02, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.9164114928671891
#  Recall (training set):0.8865372670807453
#  F1 score (training set):0.9150912452829385
#  precision (training set):0.9456240434558356
#  roc_auc score (training set):0.9689838764262854

# %% [markdown]
# **Random forest Model Evaluation Results:**
#
#
#
# | Metric        | Random forest base model | Random forest tuned model |
# | ------------- | ------- | ------- |
# | # Indep. Vars |  15     |   15     |
# | The Accuracy of the model  | 0.911  | 0.916 |
# |  Recall           |0.878 |  0.887 |
# |  F1 Score      | 0.910  |0.915 |
# |  precision           |0.944 | 0.956 |
# |  roc_auc Score      | 0.969  |0.969  |
#
#
# From the results above, the tuned Random Forest model did perform better than the base model. We can see that the tuned model has higher accuracy, recall, F1, precision and roc_auc scores comparing to the base model. The accuracy of tuned model is higher than the null error rate. So in our Random Forest models, we select the tuned model as our best model.

# %% [markdown]
# ### Step 6:  Model Selection
#
# #### 1) Compare Models:
#
# | Metric        | Logistic Regression tuned model | KNN tuned model | SVC tuned model  | Decision Tree base model  | Random Forest tuned model |
# | ------------- | ------- | ------- | ------- | ------- | ------- |
# | # Indep. Vars |  15     |   15     |   15  | 15 | 15  |
# | The Accuracy of the model  | 0.756  | 0.877 |  0.870  | 0.838 | 0.916 |
# |  Recall           |0.771 | 0.951 |  0.906 | 0.849 | 0.887 |
# |  F1 Score      | 0.762  |0.888 | 0.876 | 0.843 | 0.915 |
# |  precision           |0.755 | 0.951 |  0.849 | 0.838 | 0.956 |
# |  roc_auc Score      | 0.820  |0.935 | 0.942 | 0.838 | 0.969 |

# %% [markdown]
# As we can see above, the tuned Random Forest model performs best among all the preferred models which we selected before. So we'll choose the tuned Random Forest Model as our preferred model and use it to our training and testing dataset next.

# %% [markdown]
# #### 2) Apply the preferred model to the testing subset:

# %%
#predict on the testing set
y_pred_final = rf02.predict(X_test_new)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import multilabel_confusion_matrix

print("Random Forest Tuned model:")
mcm01 = confusion_matrix(y_test, y_pred_final)
print("Confusion Matrix\n{}".format(mcm01))
print("Classification Report")
print(classification_report(y_test, y_pred_final))
# Out:
# Random Forest Tuned model:
# Confusion Matrix
# [[202   8]
#  [ 24 161]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.93       210
#            1       0.95      0.87      0.91       185
#
#     accuracy                           0.92       395
#    macro avg       0.92      0.92      0.92       395
# weighted avg       0.92      0.92      0.92       395

# %% [markdown]
# #### 3) Apply the preferred model to the training subset:

# %%
#predict on the training set
y_pred01 = rf02.predict(X_train_new)

mcm02 = confusion_matrix(y_train, y_pred01)
print("Confusion Matrix\n{}".format(mcm02))
print("Classification Report")
print(classification_report(y_train, y_pred01))
# Out:
# Confusion Matrix
# [[777   0]
#  [  4 798]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       777
#            1       1.00      1.00      1.00       802
#
#     accuracy                           1.00      1579
#    macro avg       1.00      1.00      1.00      1579
# weighted avg       1.00      1.00      1.00      1579

# %% [markdown]
# From the Classification Report above we can see that our preferred Random Forest Model performs very well in the testing dataset, so our preferred model did work as we expected.

# %% [markdown]
# ## Step 7: Ensemble Model
#
# When we talk about an ensemble of classifiers, there are two possibilities:
#
# * An ensemble of different classifiers, which, for example, can contain logistic regression classifiers, SVM classifiers, and decision trees, all at the same time.
#
# * An ensemble of the same type of classifiers, such as Random Forest and the Bagging model. Bagging refers to the method of randomly sampling training instances with replacement. In statistics, sampling with replacement is also called bootstrapping.
#
# https://www.kaggle.com/fengdanye/machine-learning-6-basic-ensemble-learning
#
#
# In this study, there are five classifiers, they are Logistic Regression, KNN, SVM, Decision Tree, and Random Forest. First of all, we'll create bagging models by using Scikit-learn's `BaggingClassifier` and setting oob_score=True. The oob score is an estimate of the accuracy of the ensemble classifier.
#
# Then, we'll Construct an ensemble model comprising all of the models built in Step 5. We'll use sklearn's `VotingClassifier` to combine different classifiers and perform a vote on what the predicted class labels are for a record. Also, we'll create another ensemble model with 5 bagging models. We'll use `voting='hard'` for the `VotingClassifier`. The `hard` voting aggregates predections of each classifier and predicts the class that gets most votes.
#
# Lastly, we'll evaluate the models by using 5-fold cross validation based on accuracy, recall, F1, and precision.
#
#
# The following diagram presents the workflow:
#
# <img src="https://raw.githubusercontent.com/susanqisun/DAV-6150/master/assignments/picture/Untitled%20Diagram%20(6).jpg">
#
#
# ### 1. Ensemble of same classifiers by using `BaggingClassifier`
#
# We'll create bagging models for the selected models from the Step 5. We'll use an ensemble of 500 each classifiers with the bagging method.

# %%
 #Create a function for Model Evaluation Using Cross-Validation
def cross_val_score02 (model, X_train, y_train):
    accuracy_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')
    recall = cross_val_score(model, X_train, y_train, cv=5, scoring='recall')
    f1 = cross_val_score(model, X_train, y_train, cv=5, scoring='f1')
    precision = cross_val_score(model, X_train, y_train, cv=5, scoring='precision')
    print('Model Mean Accuracy (training set):{} '.format(np.mean(accuracy_scores)))
    print(' Recall (training set):{} '.format(np.mean(recall)))
    print(' F1 score (training set):{} '.format(np.mean(f1)))
    print(' precision (training set):{} '.format(np.mean(precision)))

# %% [markdown]
# #### 1.1 Logistic Regression Bagging Model

# %%
from sklearn.ensemble import BaggingClassifier

bag_LR = BaggingClassifier(LR_tuned_model02, n_estimators = 500, oob_score = True, random_state = 90)

bag_LR.fit(X_train_new, y_train)
# The oob score is an estimate of the accuracy of the ensemble classifier
print(bag_LR.oob_score_)
# Out:
# 0.7568081063964535

# %%
 # Ensemble model evaluation on the training set
cross_val_score02 (bag_LR, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.7567952581876632
#  Recall (training set):0.7718400621118013
#  F1 score (training set):0.7634579570515747
#  precision (training set):0.7557037640623325

# %% [markdown]
# #### 1.2 KNN Bagging Model

# %%
bag_knn = BaggingClassifier(KNN02, n_estimators = 500, oob_score = True, random_state = 90)

bag_knn.fit(X_train_new, y_train)
# The oob score is an estimate of the accuracy of the ensemble classifier
print(bag_knn.oob_score_)
# Out:
# 0.8942368587713743

# %%
 # Ensemble model evaluation on the training set
cross_val_score02 (bag_knn, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.8828229857343782
#  Recall (training set):0.9551319875776396
#  F1 score (training set):0.8924649957435348
#  precision (training set):0.8381589470027091

# %% [markdown]
# #### 1.3 SVM Bagging Model

# %%
bag_svm = BaggingClassifier(SVC02, n_estimators = 500, oob_score = True, random_state = 90)

bag_svm.fit(X_train_new, y_train)
# The oob score is an estimate of the accuracy of the ensemble classifier
print(bag_svm.oob_score_)
# Out:
# 0.8872704243191893

# %%
# Ensemble model evaluation on the training set
cross_val_score02 (bag_svm, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.8707936507936507
#  Recall (training set):0.9089518633540374
#  F1 score (training set):0.877139652874771
#  precision (training set):0.8477472613297594

# %% [markdown]
# #### 1.4 Decision Tree Bagging Model

# %%
bag_dt = BaggingClassifier(dtc01, n_estimators = 500, oob_score = True, random_state = 90)

bag_dt.fit(X_train_new, y_train)
# The oob score is an estimate of the accuracy of the ensemble classifier
print(bag_dt.oob_score_)
# Out:
# 0.8999366687777074

# %%
# Ensemble model evaluation on the training set
cross_val_score02 (bag_dt, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.9005746433594535
#  Recall (training set):0.8790760869565217
#  F1 score (training set):0.8998640512494704
#  precision (training set):0.9218883330412704

# %% [markdown]
# #### 1.5 Random Forest Bagging Model

# %%
bag_rf = BaggingClassifier(rf02, n_estimators = 500, oob_score = True, random_state = 90)

bag_rf.fit(X_train_new, y_train)
# The oob score is an estimate of the accuracy of the ensemble classifier
print(bag_rf.oob_score_)
# Out:
# 0.9176694110196327

# %%
# Ensemble model evaluation on the training set
cross_val_score02 (bag_rf, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.9138758288125377
#  Recall (training set):0.8828183229813664
#  F1 score (training set):0.9124639006847991
#  precision (training set):0.9445524497248636

# %% [markdown]
# ### 2. Ensemble of different bagging models
#
# We'll use sklearn's `VotingClassifier` to combine different bagging models and perform a vote on what the predicted class labels are for a record. We'll use `voting='hard'` for the `VotingClassifier`.

# %%
# build Ensemble model (Bagging)
from sklearn.ensemble import VotingClassifier

eclf01 = VotingClassifier(estimators=[('Bagging Logitic Regression', bag_LR), ('Bagging KNN', bag_knn), ('Bagging SVM', bag_svm), ('Bagging Decision Tree', bag_dt),('Bagging Random Forest', bag_rf)], voting='hard').fit(X_train_new, y_train)

# %%
# Ensemble model evaluation on the training set
cross_val_score02 (eclf01, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.9062648181635524
#  Recall (training set):0.9152251552795031
#  F1 score (training set):0.9085138785319519
#  precision (training set):0.902321833919529

# %% [markdown]
# ### 3. Ensemble of different models selected from Step 5

# %%
# build Ensemble model
eclf02 = VotingClassifier(estimators=[('Logitic Regression', LR_tuned_model02), ('KNN', KNN02), ('SVM', SVC02), ('Decision Tree', dtc01),('Random Forest', rf02)], voting='hard').fit(X_train_new, y_train)

# %%
# Ensemble model evaluation on the training set
cross_val_score02 (eclf02, X_train_new, y_train.values.ravel())
# Out:
# Model Mean Accuracy (training set):0.9056359252561783
#  Recall (training set):0.9189596273291926
#  F1 score (training set):0.9083368126119181
#  precision (training set):0.8981718021062661

# %% [markdown]
# ### 4. Compare Models
#
# **1) Compare the Ensemble Model to the Models selected from Step 5:**
#
# | Metric        | Logistic Regression tuned model | KNN tuned model | SVM tuned model  | Decision Tree base model  | Random Forest tuned model | Ensemble model
# | ------------- | ------- | ------- | ------- | ------- | ------- | ------- |
# | # Indep. Vars |  15     |   15     |   15  | 15 | 15  | 15 |
# | The Accuracy of the model  | 0.7555  | 0.8771 |  0.8702  | 0.8385 | 0.9164 | 0.9056 |
# |  Recall           |0.7706 | 0.9514 |  0.9064 | 0.8491 | 0.8865 | 0.9189 |
# |  F1 Score      | 0.7623  |0.8876 | 0.8763 | 0.8425 | 0.9151 | 0.9083 |
# |  precision           |0.7545 | 0.832 |  0.8485 | 0.8377 | 0.9456 | 0.8982 |

# %% [markdown]
# **2) Compare the Bagging Ensemble Model to the Bagging Models:**
#
# | Metric        | Bagging Logistic Regression model | Bagging KNN model | Bagging SVM model  | Bagging Decision Tree model  | Bagging Random Forest model | Bagging Ensemble model
# | ------------- | ------- | ------- | ------- | ------- | ------- | ------- |
# | # Indep. Vars |  15     |   15     |   15  | 15 | 15  | 15 |
# | The Accuracy of the model  | 0.7570  | 0.8828 |  0.8708  | 0.9006 | 0.9139 | 0.9062 |
# |  Recall           |0.7718 | 0.9551 |  0.9090 | 0.8791 | 0.8828 | 0.9152 |
# |  F1 Score      | 0.7635  |0.8925 | 0.8771 | 0.8999 | 0.9125 | 0.9085 |
# |  precision           |0.7557 | 0.8382 |  0.8477 | 0.9219 | 0.9446 | 0.9023 |

# %% [markdown]
# **Results:**
#
# > Non-bagging models vs Bagging models (Compare Table 2 to Table 1)
#
# The bagging method improves the model performance (accuracy, recall, F1, and precision) for Logistic Regression, KNN, SVM, and Decision Tree models. However, the bagging Random Forest has a decrease in accuracy, recall, F1, and precision.
#
# > Non-bagging regular models vs Non-bagging ensemble model (see Table 1)
#
# The ensemble model performs better than the Logistic Regression, KNN, SVM, and Decision Tree. However, the ensemble model did not perform as well as the Random Forest tuned model, so our ensemble model is not working as expected after we’ve combined all the various models into one.
#
# > Bagging regular models vs. Bagging ensemble model (see Table 2)
#
# The bagging ensemble model performs better than the bagging Logistic Regression, bagging KNN, bagging SVM, and bagging Decision Tree. But the bagging ensemble model did not perform as well as the bagging Random Forest tuned model.
#
# > Random Forest Model vs. Bagging Random Forest Model (final compare)
#
# The bagging Random Forest has a decrease in accuracy, recall, F1, and precision. Therefore, the Random Forest tuned Model is our final model to predict employee attrition.

# %% [markdown]
# ***
#
# ## Step 8. Conclusion
#
# ### 1. Print out the variable importance

# %%
print(rf02.feature_importances_)
importances = rf02.feature_importances_
indices = np.argsort(importances)
features = X_train_new.columns
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='g', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
# Out:
# [0.06402256 0.060856   0.06654411 0.04864688 0.06031196 0.08852481
#  0.05542923 0.09459961 0.04917453 0.08471255 0.04574711 0.0480638
#  0.0673153  0.06142172 0.10462983]

# %% [markdown]
# **Results:**
#
# From the plot above, we can see that the most important feature to predict the employee attrition is the 'OverTime_Yes', which means the employee works always over time. Next are 'JobSatisfaction' and 'JobInvolvement'.
#
# BusinessTravel
#
#
#
# ### 2. Answer research questions:
#
# **1) What are the relationships between attrition and other variables?**
#
# Our EDA analysis on Step 2(6) have already answered this question.

# %% [markdown]
# **2) What is the best model to predict employees’ attrition?**
#
# From the Step 7, we can know that the Random Forest tuned Model is the best model to predict employee attrition since it has the highest accuracy, recall, F1, and precision scores. The Model has 15 features, they are 'Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'RelationshipSatisfaction', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsWithCurrManager', and 'OverTime_Yes'.

# %% [markdown]
# **3) Which features are most contributed to the response variable?**
#
# The top three features that are most contributed to employees’ attrition are 'OverTime_Yes', 'JobSatisfaction', and 'JobInvolvement'. These results corresponds to the research findings of Firth et al.(2007), Griffeth et al.(2000), and Louis (1980).

# %% [markdown]
# ### 3. Explain the final Model by using LIME
#
# Lime supports explanations for individual predictions and support for scikit-learn is built in.
#
# Lastly, we'll use LIME to explain individual prediction.
#
# **1) Import LIME package**

# %%
import lime
import lime.lime_tabular

# %% [markdown]
# **2) Create the Explainer**

# %%
# data set with original data
df_new = df_dummy[columns_final]

# create explainer
predict_fn_rf = lambda x: rf02.predict_proba(x).astype(float)
X02 = df_new.values
explainer = lime.lime_tabular.LimeTabularExplainer(X02,feature_names = df_new.columns,class_names=['Attrition_No','Attrition_Yes'], kernel_width=5)

# %% [markdown]
# **3) Use the explainer to explain predictions**
#
# We'll use the case #18 as an example. The actual attrition value of this case is 0. Let's see what our model predicts attrition of this case.

# %%
# example
i=18

df_new.loc[[i]]
# Out:
#     Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 18   53       1219                 2          4                        1
#
#     JobInvolvement  JobLevel  JobSatisfaction  RelationshipSatisfaction  \
# 18               2         4                4                         3
#
#     TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 18                 31                      3                3              25
#
#     YearsWithCurrManager  OverTime_Yes
# 18                     7             0

# %%
# attrition actual value
y.loc[[i]]
# Out:
#     Attrition
# 18          0

# %%
# explain prediction 
choosen_instance = df_new.loc[i]
exp = explainer.explain_instance(choosen_instance, predict_fn_rf,num_features=8)
exp.show_in_notebook()
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# ...

# %% [markdown]
# **Interpretation:**
#
# <img src="https://raw.githubusercontent.com/susanqisun/DAV-6150/master/assignments/picture/Screen%20Shot%202020-08-13%20at%209.05.51%20PM.png" width="800">
#
#
# Since the results of LIME are not shown on Github, we use the screenshot of our local Jupyter Notebook here to explain the results. From the results above, we can see that our Random Forest Model predicted the probability of attrition_No (0) of this case is 79%, which is higher than the threshold 50% and than the probability of attrition_Yes (21%). Therefore, the predicted attrition value is 0 (attrition_No), which is the same as the actual value.
#
# For the probabilities of not leaving this company, the first factor for this person is 'OverTime_Yes=0' meaning this person did not always work over time. Next factor is 'YearsWithCurrManager'. The Years With Current Manager of this person is 7, which is long enough. Also, these two factors are the top ones affecting the probabilities of attrition. However, the number of years that this person stays at the company is 25, which has increased his chances of leaving this company significantly.
